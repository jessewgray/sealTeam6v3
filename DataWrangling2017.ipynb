# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from functools import reduce
import matplotlib as plt

# %%
#2016 Oscar Awards
cast_awards=pd.read_csv('./DataSources/2017CastAwards.csv')
cast_awards
# Out:
#                                        Title  Best Director  Best Actor  \
# 0                         The Shape of Water              1           0
# 1                               Darkest Hour              0           1
# 2                                    Dunkirk              0           0
# 3                             Phantom Thread              0           0
# 4                                   The Post              0           0
# 5                       Call Me by Your Name              0           0
# 6                                  Lady Bird              0           0
# 7  Three Billboards Outside Ebbing, Missouri              0           0
# 8                                    Get Out              0           0
#
#    Best Actress  Best Supporting Actor  Best Supporting Actress
# 0             0                      0                        0
# 1             0                      0                        0
# 2             0                      0                        0
# 3             0                      0                        0
# 4             0                      0                        0
# 5             0                      0                        0
# 6             0                      0                        0
# 7             1                      1                        0
# 8             0                      0                        0

# %%
#OMBD Calls - done on movies list
theMoviesDF_OMBD = pd.read_csv('./DataSources/OMBD_2017Films.csv', encoding='utf-8')
theMoviesDF_OMBD
# Out:
#                                               Actors  \
# 0  Sally Hawkins, Michael Shannon, Richard Jenkin...
# 1  Gary Oldman, Kristin Scott Thomas, Ben Mendels...
# 2  Fionn Whitehead, Damien Bonnard, Aneurin Barna...
# 3  Vicky Krieps, Daniel Day-Lewis, Lesley Manvill...
# 4  Meryl Streep, Tom Hanks, Sarah Paulson, Bob Od...
# 5  Armie Hammer, Timothée Chalamet, Michael Stuhl...
# 6  Saoirse Ronan, Laurie Metcalf, Tracy Letts, Lu...
# 7  Frances McDormand, Caleb Landry Jones, Kerry C...
# 8  Daniel Kaluuya, Allison Williams, Catherine Ke...
#
#                                               Awards    Box Office  \
# 0  Won 4 Oscars. Another 101 wins & 293 nominations.   $57,393,976
# 1    Won 2 Oscars. Another 40 wins & 63 nominations.   $28,086,332
# 2   Won 3 Oscars. Another 51 wins & 197 nominations.  $188,042,171
# 3     Won 1 Oscar. Another 46 wins & 93 nominations.      $947,190
# 4  Nominated for 2 Oscars. Another 16 wins & 97 n...   $80,369,969
# 5    Won 1 Oscar. Another 82 wins & 196 nominations.           NaN
# 6  Nominated for 5 Oscars. Another 102 wins & 191...   $48,285,330
# 7  Won 2 Oscars. Another 104 wins & 193 nominations.   $52,000,189
# 8   Won 1 Oscar. Another 122 wins & 181 nominations.  $175,428,355
#
#                         Country              Director  \
# 0                           USA    Guillermo del Toro
# 1                       UK, USA            Joe Wright
# 2  UK, Netherlands, France, USA     Christopher Nolan
# 3                       USA, UK  Paul Thomas Anderson
# 4                       USA, UK      Steven Spielberg
# 5    Italy, France, Brazil, USA       Luca Guadagnino
# 6                           USA          Greta Gerwig
# 7                       UK, USA       Martin McDonagh
# 8                    Japan, USA          Jordan Peele
#
#                                           Genre  Rated  \
# 0  Adventure, Drama, Fantasy, Romance, Thriller      R
# 1                Biography, Drama, History, War  PG-13
# 2         Action, Drama, History, Thriller, War  PG-13
# 3                                Drama, Romance      R
# 4           Biography, Drama, History, Thriller  PG-13
# 5                                Drama, Romance      R
# 6                                 Comedy, Drama      R
# 7                          Comedy, Crime, Drama      R
# 8                     Horror, Mystery, Thriller      R
#
#                                        Title  \
# 0                         The Shape of Water
# 1                               Darkest Hour
# 2                                    Dunkirk
# 3                             Phantom Thread
# 4                                   The Post
# 5                       Call Me by Your Name
# 6                                  Lady Bird
# 7  Three Billboards Outside Ebbing, Missouri
# 8                                    Get Out
#
#                                            Writer(s)  Year  imdbRating
# 0  Guillermo del Toro (screenplay by), Vanessa Ta...  2017         7.4
# 1                                   Anthony McCarten  2017         7.4
# 2                                  Christopher Nolan  2017         7.9
# 3                               Paul Thomas Anderson  2017         7.5
# 4                            Liz Hannah, Josh Singer  2017         7.2
# 5  James Ivory (screenplay by), André Aciman (bas...  2017         8.0
# 6                                       Greta Gerwig  2017         7.5
# 7                                    Martin McDonagh  2017         8.2
# 8                                       Jordan Peele  2017         7.7

# %%
#TMDB Calls
theMoviesDF_TMDB=pd.read_csv('./DataSources/2017moviesDF_TMDB.csv', encoding='utf-8').rename(columns={"Name":"Title"})
theMoviesDF_TMDB
# Out:
#                                        Title                      Company  \
# 0                         The Shape of Water  Double Dare You Productions
# 1                               Darkest Hour       Perfect World Pictures
# 2                                    Dunkirk    RatPac-Dune Entertainment
# 3                             Phantom Thread       Ghoulardi Film Company
# 4                                   The Post         Amblin Entertainment
# 5                       Call Me by Your Name               La Cinéfacture
# 6                                  Lady Bird                    IAC Films
# 7  Three Billboards Outside Ebbing, Missouri           Blueprint Pictures
# 8                                    Get Out        Monkeypaw Productions
#
#      Revenue     Budget  Runtime  Vote Average  Vote Count  Popularity  \
# 0  194989655   19500000      123           7.3        5684      21.903
# 1  147568410   30000000      125           7.3        2161      13.953
# 2  525573161  100000000      107           7.4        7684      21.633
# 3   46261438   35000000      131           7.2        1215      10.017
# 4  174503458   50000000      116           7.0        1972      11.181
# 5   41063475    4000000      132           8.3        3722      16.849
# 6   76858273   10000000       94           7.3        2956      17.112
# 7  158526998   15000000      115           8.2        4216      15.942
# 8  255017329    4500000      104           7.4        6950      16.420
#
#                                                Genre Release Date  Movie ID
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...   2017-12-01    399055
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...   2017-11-22    399404
# 2  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   2017-07-19    374720
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   2017-12-25    400617
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...   2017-12-22    446354
# 5  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   2017-09-01    398818
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   2017-09-08    391713
# 7  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   2017-11-10    359940
# 8  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...   2017-02-24    419430

# %%
#fix any title discrepancies between OMBD and TMDB dataframes by replacing incorrect OMBD names with TMDB names
bad_names_OMBD=[]
correct_names_TMDB=[]

for i in theMoviesDF_OMBD["Title"].values:
    if i in theMoviesDF_TMDB["Title"].values:
        pass
    else:
        bad_names_OMBD.append(i)


for i in theMoviesDF_TMDB["Title"].values:
    if i in theMoviesDF_OMBD["Title"].values:
        pass
    else:
        correct_names_TMDB.append(i)

bad_names_OMBD
# Out:
# []

# %%
correct_names_TMDB
# Out:
# []

# %% [markdown]
# # EXTRACTING INFO FROM API CALLS

# %%
#DataFrame by Genre (OMBD)
genreMovies=theMoviesDF_OMBD[['Title', 'Genre']]

for i in range(len(genreMovies['Genre'])):
    x=genreMovies['Genre'][i].split(", ")
    genreMovies['Genre'][i]=x

s=genreMovies.apply(lambda x:pd.Series(x['Genre']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'Genre'
BP_genres=genreMovies.drop('Genre', axis=1).join(s)
BP_genres=pd.get_dummies(BP_genres, columns=['Genre'])
BP_genres=BP_genres.groupby('Title').sum()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2961: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Dataframe by IMBD rating (OMBD)
BP_IMBD=theMoviesDF_OMBD[['Title','imdbRating']]

#Dataframe by Rating (OMBD)
BP_Rating_qual=theMoviesDF_OMBD[['Title','Rated']]
#consolidate certain ratings
BP_Rating_qual['Rated']=BP_Rating_qual['Rated'].replace({'GP':'PG',
                                                        'M/PG': 'PG',
                                                        'TV-MA': 'R',
                                                        'TV-PG': 'PG',
                                                        'PASSED':'APPROVED',
                                                        'NOT RATED': 'UNRATED'})
BP_Rating=pd.get_dummies(BP_Rating_qual, columns=['Rated'])

#Dataframe by Country (OMBD)
BP_Country_qual=theMoviesDF_OMBD[['Title','Country']]
BP_Country=pd.get_dummies(BP_Country_qual, columns=['Country'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
#Dataframe by Revenue and Budget (TMDB)
BP_Revenue_Budget=theMoviesDF_TMDB[['Title','Revenue', 'Budget']]

#Dataframe by Popularity (TMDB)
BP_Popularity = theMoviesDF_TMDB[['Title','Popularity']]

#Dataframe by Run Time (TMDB)
BP_Runtime = theMoviesDF_TMDB[['Title','Runtime']]

# %%
#Dataframe for Release Month (TMDB)
BP_RelMonth_qual = theMoviesDF_TMDB[['Title','Release Date']]
for i in range(len(BP_RelMonth_qual['Release Date'])):
    x=BP_RelMonth_qual['Release Date'][i].split("-")
    BP_RelMonth_qual['Release Date'][i]=x[1]

BP_RelMonth=pd.get_dummies(BP_RelMonth_qual, columns=['Release Date'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2961: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#create a spreadsheet of all info (cannot have string as values)
theMoviesDF=pd.merge(cast_awards, BP_IMBD, on= 'Title', how='inner')
dfs=[theMoviesDF, BP_Popularity, BP_Rating, BP_RelMonth, BP_Revenue_Budget, BP_Runtime, BP_genres]
theMoviesDF= reduce(lambda df1,df2: pd.merge(df1,df2,on=['Title'], how='left'), dfs)
theMoviesDF.fillna(0, inplace=True)
theMoviesDF.to_csv('theMovies2017.csv', index=False)
theMoviesDF
# Out:
#                                        Title  Best Director  Best Actor  \
# 0                         The Shape of Water              1           0
# 1                               Darkest Hour              0           1
# 2                                    Dunkirk              0           0
# 3                             Phantom Thread              0           0
# 4                                   The Post              0           0
# 5                       Call Me by Your Name              0           0
# 6                                  Lady Bird              0           0
# 7  Three Billboards Outside Ebbing, Missouri              0           0
# 8                                    Get Out              0           0
#
#    Best Actress  Best Supporting Actor  Best Supporting Actress  imdbRating  \
# 0             0                      0                        0         7.4
# 1             0                      0                        0         7.4
# 2             0                      0                        0         7.9
# 3             0                      0                        0         7.5
# 4             0                      0                        0         7.2
# 5             0                      0                        0         8.0
# 6             0                      0                        0         7.5
# 7             1                      1                        0         8.2
# 8             0                      0                        0         7.7
#
#    Popularity  Rated_PG-13  Rated_R    ...      Genre_Comedy  Genre_Crime  \
# 0      21.903            0        1    ...                 0            0
# 1      13.953            1        0    ...                 0            0
# 2      21.633            1        0    ...                 0            0
# 3      10.017            0        1    ...                 0            0
# 4      11.181            1        0    ...                 0            0
# 5      16.849            0        1    ...                 0            0
# 6      17.112            0        1    ...                 1            0
# 7      15.942            0        1    ...                 1            1
# 8      16.420            0        1    ...                 0            0
#
#    Genre_Drama  Genre_Fantasy  Genre_History  Genre_Horror  Genre_Mystery  \
# 0            1              1              0             0              0
# 1            1              0              1             0              0
# 2            1              0              1             0              0
# 3            1              0              0             0              0
# 4            1              0              1             0              0
# 5            1              0              0             0              0
# 6            1              0              0             0              0
# 7            1              0              0             0              0
# 8            0              0              0             1              1
#
#    Genre_Romance  Genre_Thriller  Genre_War
# 0              1               1          0
# 1              0               0          1
# 2              0               1          1
# 3              1               0          0
# 4              0               1          0
# 5              1               0          0
# 6              0               0          0
# 7              0               0          0
# 8              0               1          0
#
# [9 rows x 31 columns]
